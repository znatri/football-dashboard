# %% [markdown]
# # Get dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dW7QXYbZXx1GFnSwIeXf")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(9)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-9 in yolov5pytorch:: 100%|██████████| 636/636 [00:00<00:00, 4634.70it/s]

# %%
# move dirs for yolo
import shutil

shutil.move('football-players-detection-9/train', 'football-players-detection-9/football-players-detection-9/train')
shutil.move('football-players-detection-9/test', 'football-players-detection-9/football-players-detection-9/test')
shutil.move('football-players-detection-9/valid', 'football-players-detection-9/football-players-detection-9/valid')
# Out:
# 'football-players-detection-9/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
from IPython.display import display, Image
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# Setup complete ✅ (16 CPUs, 31.2 GB RAM, 120.5/225.7 GB disk)
# Setup complete ✅ (16 CPUs, 31.2 GB RAM, 120.5/225.7 GB disk)

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=800 cache=False batch=4 plots=True
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.2.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# ...

# %%
# !yolo task=detect mode=val model="/home/hardik/projects/football_analysis/training/runs/detect/train3/weights/best.pt" data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# YOLOv5x summary (fused): 358 layers, 97156460 parameters, 0 gradients, 246.0 GFLOPs
# val: Scanning /home/hardik/projects/football_analysis/training/football-players-
# /home/hardik/miniconda3/envs/futbalanalytics/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.922      0.763      0.818       0.63
#                   ball         43         39      0.888      0.256      0.361      0.216
# ...

# %%
# !yolo task=detect mode=val model="/home/hardik/projects/football_analysis/training/runs/detect/train2/weights/best.pt" data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /home/hardik/projects/football_analysis/training/football-players-
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         43       1025      0.923      0.733      0.829      0.596
#                   ball         43         39      0.851      0.294      0.487      0.214
#             goalkeeper         43         32      0.925      0.777      0.893      0.696
#                 player         43        853      0.957      0.944      0.978      0.796
#                referee         43        101      0.959      0.917      0.958      0.678
# Speed: 1.4ms preprocess, 52.5ms inference, 0.1ms loss, 11.8ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

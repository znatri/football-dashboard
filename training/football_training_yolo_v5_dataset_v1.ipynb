# %% [markdown]
# # Get dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dW7QXYbZXx1GFnSwIeXf")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# move dirs for yolo
import shutil

shutil.move('football-players-detection-1/train', 'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test', 'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid', 'football-players-detection-1/football-players-detection-1/valid')

# %% [markdown]
# # Training

# %%
from IPython.display import display, Image
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# Setup complete ✅ (16 CPUs, 31.2 GB RAM, 121.5/225.7 GB disk)
# Setup complete ✅ (16 CPUs, 31.2 GB RAM, 121.5/225.7 GB disk)

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=800 cache=False batch=4 plots=True
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.2.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# engine/trainer: task=detect, mode=train, model=yolov5x.pt, data=/home/hardik/projects/football_analysis/training/football-players-detection-1/data.yaml, epochs=100, patience=50, batch=4, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train4
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      8800  ultralytics.nn.modules.conv.Conv             [3, 80, 6, 2, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  4    309120  ultralytics.nn.modules.block.C3              [160, 160, 4]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  8   2259200  ultralytics.nn.modules.block.C3              [320, 320, 8]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1 12  13125120  ultralytics.nn.modules.block.C3              [640, 640, 12]
#   7                  -1  1   7375360  ultralytics.nn.modules.conv.Conv             [640, 1280, 3, 2]
#   8                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4]
#   9                  -1  1   4099840  ultralytics.nn.modules.block.SPPF            [1280, 1280, 5]
#  10                  -1  1    820480  ultralytics.nn.modules.conv.Conv             [1280, 640, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  4   5332480  ultralytics.nn.modules.block.C3              [1280, 640, 4, False]
#  14                  -1  1    205440  ultralytics.nn.modules.conv.Conv             [640, 320, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  4   1335040  ultralytics.nn.modules.block.C3              [640, 320, 4, False]
#  18                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  4   4922880  ultralytics.nn.modules.block.C3              [640, 640, 4, False]
#  21                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  4  19676160  ultralytics.nn.modules.block.C3              [1280, 1280, 4, False]
#  24        [17, 20, 23]  1  11025820  ultralytics.nn.modules.head.Detect           [4, [320, 640, 1280]]
# YOLOv5x summary: 493 layers, 97203260 parameters, 97203244 gradients, 246.9 GFLOPs
#
# Transferred 817/823 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train4', view at http://localhost:6006/
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/hardik/miniconda3/envs/futbalanalytics/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# train: Scanning
800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.857      0.781      0.819      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.33G     0.6155     0.3083     0.7787        100        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.917      0.754      0.812      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.33G     0.6007     0.3013     0.7786        129        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.886      0.795      0.833      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      7.19G     0.6178     0.3055     0.7793        125        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.876      0.761      0.812      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      7.33G     0.6044     0.2999     0.7784        145        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.901      0.766      0.824       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      7.11G      0.591     0.2961     0.7781        146        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.919      0.773       0.83      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.19G     0.5961     0.2994     0.7789        191        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.882      0.781      0.818      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.19G     0.6003     0.2971     0.7762        200        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.915      0.772      0.822       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.18G     0.6026     0.2981     0.7781        116        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.907      0.784      0.833      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.18G     0.5881     0.2932     0.7769        242        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.913      0.776      0.834      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.34G     0.5894     0.2893     0.7766        148        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.886       0.78      0.833      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.19G     0.5666     0.2804     0.7777        215        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.872      0.791      0.834      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.19G     0.5798     0.2874     0.7767        166        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.968      0.756      0.825      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.19G      0.579      0.284     0.7761        125        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.883      0.777      0.831      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100       7.2G     0.5687     0.2821     0.7757        151        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.95      0.757      0.829      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.19G     0.5621     0.2809     0.7753        187        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.88      0.786      0.832      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.17G     0.5632     0.2785     0.7762        239        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.881      0.784      0.824      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.19G     0.5615      0.279      0.775        133        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.871      0.783      0.827      0.627
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.11G      0.534     0.2741     0.7746         90        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.885      0.763       0.82      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       7.1G     0.5304       0.27     0.7714         91        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.911      0.754      0.809      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.29G     0.5174     0.2663     0.7712         92        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.909      0.764      0.817      0.626
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.12G     0.5328      0.271     0.7724         91        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905        0.9      0.769      0.823      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.28G     0.5081     0.2622     0.7741         85        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.88      0.763      0.815      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.11G     0.5036     0.2593     0.7717         97        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891      0.774      0.822      0.622
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.27G     0.5123     0.2619     0.7725         95        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.927      0.769      0.835       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100       7.1G      0.498     0.2562     0.7716         92        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.907      0.775      0.831      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100       7.1G     0.4901     0.2545     0.7713         95        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.899      0.773      0.832      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.26G     0.4985     0.2571     0.7714         93        800: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.916      0.758      0.825       0.63
#
# 100 epochs completed in 1.324 hours.
# Optimizer stripped from runs/detect/train4/weights/last.pt, 195.0MB
# Optimizer stripped from runs/detect/train4/weights/best.pt, 195.0MB
#
# Validating runs/detect/train4/weights/best.pt...
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.3 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3070 Ti, 7971MiB)
# YOLOv5x summary (fused): 358 layers, 97156460 parameters, 0 gradients, 246.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.907      0.784      0.833      0.632
#                   ball         38         35      0.865      0.257      0.387      0.187
#             goalkeeper         38         27       0.85      0.963      0.983      0.798
#                 player         38        754      0.979      0.969      0.992      0.827
#                referee         38         89      0.934      0.947       0.97      0.715
# Speed: 0.3ms preprocess, 13.2ms inference, 0.0ms loss, 20.6ms postprocess per image
# Results saved to runs/detect/train4
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect mode=val model="/home/hardik/projects/football_analysis/training/runs/detect/train3/weights/best.pt" data={dataset.location}/data.yaml
